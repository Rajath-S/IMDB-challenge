# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import norm
import seaborn as sns
#from google.colab import drive
#drive.mount('/Datascience')

# %%
from google.colab import files
files.upload()

# %%
# !ls
# Out:
# sample_data

# %%
df=pd.read_csv("ds_final.csv")

# %%
df = pd.read_csv('imdb-data.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# hello world

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0          False
# Rank                False
# Title               False
# Genre               False
# Description         False
# Director            False
# Actors              False
# Year                False
# Runtime_Minutes     False
# Rating              False
# Votes               False
# Revenue_Millions    False
# Metascore           False
# dtype: bool

# %%
print("Attribute \t Number of NaN values")
df.isna().sum()
# Out:
# Attribute 	 Number of NaN values
# Unnamed: 0          0
# Rank                0
# Title               0
# Genre               0
# Description         0
# Director            0
# Actors              0
# Year                0
# Runtime_Minutes     0
# Rating              0
# Votes               0
# Revenue_Millions    0
# Metascore           0
# dtype: int64

# %%
df=df.rename(columns = {'Revenue (Millions)':'Revenue_Millions'})

# %%
df=df.rename(columns = {'Runtime (Minutes)':'Runtime_Minutes'})

# %%
genre_dict={}
for index,rows in df.iterrows():
    str=rows['Genre'].split(",")
    for ele in str:
        if(ele not in genre_dict):
            genre_dict[ele]=1
        else:
            genre_dict[ele]+=1
print(genre_dict)
# Out:
# {'Action': 303, 'Adventure': 259, 'Sci-Fi': 120, 'Mystery': 106, 'Horror': 119, 'Thriller': 195, 'Animation': 49, 'Comedy': 279, 'Family': 51, 'Fantasy': 101, 'Drama': 513, 'Music': 16, 'Biography': 81, 'Romance': 141, 'History': 29, 'Crime': 150, 'Western': 7, 'War': 13, 'Musical': 5, 'Sport': 18}

# %%
plt.figure(figsize=(10,6))
plt.bar(range(len(genre_dict)), list(genre_dict.values()), align='center')
plt.xticks(range(len(genre_dict)), list(genre_dict.keys()),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f0d1573cfd0>,
# ...
#  <a list of 20 Text xticklabel objects>)

# %%
actiondf = df['Genre'].str.contains("Action").fillna(False)
f, ax = plt.subplots(figsize=(10, 6))
sns.countplot(x='Year', data=df[actiondf], palette="Reds_d")
actiondf.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Genre, dtype: bool

# %% [markdown]
# **We got to label x and y axes**

# %%
dramadf = df['Genre'].str.contains("Drama").fillna(False)
f, ax = plt.subplots(figsize=(10, 6))
sns.countplot(x='Year', data=df[dramadf], palette="Blues_d")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
for i in genre_dict.keys():
    some = df['Genre'].str.contains(i).fillna(False)
    f, ax = plt.subplots(figsize=(10, 6))
    sns.countplot(x='Year', data=df[some], palette="Blues_d")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
d1=df.hist(column="Metascore",bins=30)
for d in d1.flatten():
  d.set_xlabel("Metascore")
  d.set_ylabel("Number of Movies")

# %%
for i in genre_dict.keys():
    some = df['Genre'].str.contains(i).fillna(False)
    '''f, ax = plt.subplots(figsize=(10, 6))
    sns.countplot(x='Year', data=df[some], palette="Blues_d")'''
    df[some].hist(column="Revenue_Millions")

# %%
df["Revenue_Millions"].fillna(df["Revenue_Millions"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Unnamed: 0.1        0
# Unnamed: 0.1.1      0
# Rank                0
# Title               0
# Genre               0
# Description         0
# Director            0
# Actors              0
# Year                0
# Runtime_Minutes     0
# Rating              0
# Votes               0
# Revenue_Millions    0
# Metascore           0
# dtype: int64

# %%
df["Metascore"].fillna(df["Metascore"].mean(),inplace=True)

# %%
for i in genre_dict.keys():
    some = df['Genre'].str.contains(i).fillna(False)
    '''f, ax = plt.subplots(figsize=(10, 6))
    sns.countplot(x='Year', data=df[some], palette="Blues_d")'''
    df[some].hist(column="Revenue_Millions")

# %%
df.hist(column="Metascore")

# %%
plt.scatter(df.Revenue_Millions, df.Metascore) 
plt.show()

# %% [markdown]
# I guess metascore is not related to revenue, dont think scatter plots are good visalizations in this scenario

# %%
plt.scatter(df.Revenue_Millions, df.Rating) 
plt.show()

# %%
years={}
for y in range(2006,2017):
  if y not in years:
    years[y]=0
for index,rows in df.iterrows():
    curr=rows['Year']
    years[curr]+=1
print(years)
# Out:
# {2006: 44, 2007: 53, 2008: 52, 2009: 51, 2010: 60, 2011: 63, 2012: 64, 2013: 91, 2014: 98, 2015: 127, 2016: 297}

# %%
plt.figure(figsize=(10,6))
plt.bar(range(len(years)), list(years.values()), align='center')
plt.xticks(range(len(years)), list(years.keys()),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f3133c74470>,
# ...
#  <a list of 11 Text xticklabel objects>)

# %% [markdown]
# THE ABOVE SHOWS REVENUE REVENUE PER YEAR IRRESPECTIVE OF ANY OTHER ATTRIBUTE

# %%
from google.colab import files
files.upload()

# %%
df=pd.read_csv("ds.csv")

# %%
df["Director"].value_counts()
# Out:
# Ridley Scott            8
# Michael Bay             6
# David Yates             6
# Paul W.S. Anderson      6
# M. Night Shyamalan      6
# David Fincher           5
# Martin Scorsese         5
# Denis Villeneuve        5
# Antoine Fuqua           5
# Justin Lin              5
# Zack Snyder             5
# J.J. Abrams             5
# Danny Boyle             5
# Christopher Nolan       5
# Woody Allen             5
# Peter Berg              5
# Ron Howard              4
# Tim Burton              4
# Joe Wright              4
# D.J. Caruso             4
# Francis Lawrence        4
# Peter Jackson           4
# Nicholas Stoller        4
# Matthew Vaughn          4
# Dennis Dugan            4
# Gore Verbinski          4
# Jon Favreau             4
# David O. Russell        4
# Adam McKay              4
# Mike Flanagan           4
#                        ..
# Frank Darabont          1
# Kyle Patrick Alvarez    1
# Matteo Garrone          1
# Hideaki Anno            1
# ...

# %%
compare_movies_rating = ['Runtime_Minutes', 'Votes','Revenue_Millions', 'Metascore']
for compare in compare_movies_rating:
        sns.jointplot(x='Rating', y=compare, data=df[actiondf], color='b', size=8)
        plt.title("Action Movies")

# %%
dir_dict={}
for index,rows in df.iterrows():
    str=rows["Director"]
    ele=str
    if(ele not in dir_dict):
      dir_dict[ele]=1
    else:
      dir_dict[ele]+=1
print(dir_dict)
# Out:
# {'James Gunn': 3, 'Ridley Scott': 8, 'M. Night Shyamalan': 6, 'Christophe Lourdelet': 1, 'David Ayer': 3, 'Yimou Zhang': 1, 'Damien Chazelle': 2, 'Sean Foley': 1, 'James Gray': 1, 'Morten Tyldum': 2, 'David Yates': 6, 'Theodore Melfi': 1, 'Gareth Edwards': 2, 'Ron Clements': 2, 'Nacho Vigalondo': 1, 'Chris Renaud': 1, 'Mel Gibson': 2, 'Paul Greengrass': 3, 'Garth Davis': 1, 'Denis Villeneuve': 5, 'Stephen Gaghan': 1, 'Kenneth Lonergan': 1, 'Ben Young': 1, 'Walt Dohrn': 1, 'Roland Emmerich': 3, 'Dominique Abel': 1, 'S.S. Rajamouli': 1, 'Phillip Guzman': 1, 'Jon Lucas': 1, 'Justin Kurzel': 2, 'John Hamburg': 1, 'Tom Ford': 1, 'Bryan Singer': 3, 'Tim Miller': 1, 'Paul W.S. Anderson': 6, 'Anthony Russo': 2, 'Christopher Nolan': 5, 'Scott Derrickson': 2, 'Antoine Fuqua': 5, 'Patrick Read Johnson': 1, 'Greg Tiernan': 1, 'Barry Jenkins': 1, 'Shawn Burkett': 1, 'John Lee Hancock': 3, 'Ricardo de Montreuil': 1, 'Rob Marshall': 2, 'John Madden': 1, 'Scott Hicks': 2, 'Justin Lin': 5, 'Sean Penn
# ...

# %%
genre_dict_rev={}
for index,rows in df.iterrows():
    str=rows['Genre'].split(",")
    for ele in str:
        if(ele not in genre_dict_rev):
            genre_dict_rev[ele]=[]
            if(not np.isnan(rows["Revenue_Millions"])):
              genre_dict_rev[ele].append(rows["Revenue_Millions"])
        else:
            if(not np.isnan(rows["Revenue_Millions"])):
              genre_dict_rev[ele].append(rows["Revenue_Millions"])
print(genre_dict_rev)
# Out:
# {'Action': [333.13, 325.02, 45.13, 8.01, 532.17, 2.87, 162.16, 103.14, 6.5, 54.65, 155.33, 363.02, 26.84, 408.08, 232.6, 93.38, 241.06, 158.8, 936.63, 30.35, 43.0, 533.32, 330.25, 128.25, 153.63, 61.28, 40.07, 309.4, 623.28, 423.03, 128.34, 292.57, 350.03, 652.18, 760.51, 86.2, 47.17, 458.99, 36.25, 181.02, 45.43, 126.59, 10.16, 210.59, 11.15, 448.13, 245.43, 238.67, 257.7, 107.5, 34.26, 46.88, 41.8, 101.79, 31.49, 23.62, 1.8, 233.91, 58.4, 167.01, 65.03, 52.82, 200.07, 93.42, 208.54, 110.42, 180.19, 13.65, 176.64, 127.38, 100.19, 318.3, 66.0, 146.41, 155.18, 318.76, 206.36, 31.14, 259.75, 33.04, 48.04, 9.24, 52.0, 241.41, 50.86, 195.0, 47.95, 26.62, 85.71, 89.73, 110.82, 202.85, 65.17, 176.74, 0.54, 179.88, 304.36, 138.45, 89.02, 191.62, 408.99, 209.02, 72.66, 36.38, 14.9, 47.38, 17.36, 2.13, 291.02, 101.53, 125.07, 62.49, 4.56, 34.91, 209.81, 5.69, 37.55, 27.36, 350.12, 26.9, 155.02, 66.47, 73.1, 336.53, 20.32, 17.18, 228.76, 262.03, 26.38, 3.85, 102.41, 14.27, 134.57, 2.2, 39.29, 
# ...

# %%
genre_dict_revenue_averages={}
for genre in genre_dict_rev:
  genre_dict_revenue_averages[genre]=sum(genre_dict_rev[genre])/len(genre_dict_rev[genre])
print(genre_dict_revenue_averages)
# Out:
# {'Action': 124.49447552447558, 'Adventure': 154.1770238095239, 'Sci-Fi': 135.55254545454545, 'Mystery': 54.62764044943817, 'Horror': 36.7052688172043, 'Thriller': 69.57725490196079, 'Animation': 191.22340425531914, 'Comedy': 75.7507843137255, 'Family': 126.17571428571424, 'Fantasy': 131.85010752688171, 'Drama': 49.844204545454566, 'Music': 47.07, 'Biography': 55.80160000000001, 'Romance': 42.50302325581396, 'History': 52.92384615384614, 'Crime': 61.80476923076924, 'Western': 111.824, 'War': 53.43300000000001, 'Musical': 81.642, 'Sport': 65.04249999999999}

# %%
rf=df[df['Revenue_Millions'].notnull()]

# %%
for index,rows in df.iterrows():
  sum1=0
  if(np.isnan(rows["Revenue_Millions"])):
    
    for gen in rows["Genre"].split(','):
      sum1+=genre_dict_revenue_averages[gen]
    df.set_value(index, 'Revenue_Millions', sum1/len(list(rows["Genre"].split(','))))
    #rows["Revenue_Millions"]=sum/len(list(rows["Genre"].split(',')))

# %%
df.isna().sum()
# Out:
# Rank                 0
# Title                0
# Genre                0
# Description          0
# Director             0
# Actors               0
# Year                 0
# Runtime_Minutes      0
# Rating               0
# Votes                0
# Revenue_Millions     0
# Metascore           64
# dtype: int64

# %%
df.describe()
# Out:
#               Rank         Year  Runtime_Minutes       Rating         Votes  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000       113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962        18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000        66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000       100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000       111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000       123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000       191.000000     9.000000  1.791916e+06
#
#        Revenue_Millions   Metascore
# count       1000.000000  936.000000
# mean          81.039254   58.985043
# std           96.852920   17.194757
# min            0.000000   11.000000
# 25%           17.442500   47.000000
# 50%           53.912414   59.500000
# ...

# %%
genre_dict_met={}
for index,rows in df.iterrows():
    str=rows['Genre'].split(",")
    for ele in str:
        if(ele not in genre_dict_met):
            genre_dict_met[ele]=[]
            if(not np.isnan(rows["Metascore"])):
              genre_dict_met[ele].append(rows["Metascore"])
        else:
            if(not np.isnan(rows["Metascore"])):
              genre_dict_met[ele].append(rows["Metascore"])
print(genre_dict_met)
# Out:
# {'Action': [76.0, 40.0, 42.0, 78.0, 65.0, 70.0, 58.0, 32.0, 36.0, 52.0, 65.0, 49.0, 75.0, 72.0, 54.0, 45.0, 68.0, 81.0, 23.0, 68.0, 82.0, 44.0, 58.0, 90.0, 68.0, 60.0, 50.0, 69.0, 53.0, 60.0, 74.0, 67.0, 59.0, 83.0, 51.0, 32.0, 66.0, 70.0, 57.0, 56.0, 44.0, 44.0, 52.0, 78.0, 32.0, 61.0, 82.0, 56.0, 42.0, 82.0, 29.0, 64.0, 69.0, 81.0, 63.0, 74.0, 47.0, 80.0, 46.0, 48.0, 60.0, 60.0, 79.0, 71.0, 64.0, 71.0, 66.0, 52.0, 71.0, 79.0, 33.0, 65.0, 43.0, 61.0, 49.0, 54.0, 25.0, 70.0, 41.0, 66.0, 51.0, 51.0, 56.0, 68.0, 75.0, 35.0, 35.0, 64.0, 38.0, 75.0, 53.0, 41.0, 68.0, 40.0, 40.0, 81.0, 69.0, 54.0, 71.0, 62.0, 57.0, 47.0, 33.0, 34.0, 40.0, 47.0, 72.0, 55.0, 57.0, 60.0, 45.0, 84.0, 33.0, 66.0, 53.0, 53.0, 34.0, 72.0, 75.0, 46.0, 84.0, 52.0, 59.0, 35.0, 30.0, 72.0, 66.0, 38.0, 62.0, 57.0, 36.0, 64.0, 33.0, 35.0, 83.0, 64.0, 27.0, 53.0, 60.0, 51.0, 63.0, 39.0, 61.0, 56.0, 65.0, 50.0, 38.0, 65.0, 45.0, 48.0, 28.0, 46.0, 85.0, 63.0, 73.0, 56.0, 41.0, 59.0, 74.0, 57.0, 28.0, 41.0, 36.0, 48.0, 65
# ...

# %%
def sum(l):
  sum2 =0
  for i in l:
    sum2+=i
  return sum2
genre_dict_metascore_averages={}
for genre in genre_dict_met:
  genre_dict_metascore_averages[genre]=sum(genre_dict_met[genre])/len(genre_dict_met[genre])
print(genre_dict_metascore_averages)
# Out:
# {'Action': 53.83044982698962, 'Adventure': 57.670682730923694, 'Sci-Fi': 58.228070175438596, 'Mystery': 59.27272727272727, 'Horror': 56.68518518518518, 'Thriller': 58.677595628415304, 'Animation': 70.78260869565217, 'Comedy': 57.6044776119403, 'Family': 55.62, 'Fantasy': 55.142857142857146, 'Drama': 63.49789029535865, 'Music': 60.6875, 'Biography': 68.94366197183099, 'Romance': 55.458015267175576, 'History': 70.85714285714286, 'Crime': 57.787234042553195, 'Western': 53.5, 'War': 64.5, 'Musical': 60.0, 'Sport': 61.5625}

# %%
for index,rows in df.iterrows():
  sum1=0
  if(np.isnan(rows["Metascore"])):
    
    for gen in rows["Genre"].split(','):
      sum1+=genre_dict_metascore_averages[gen]
    df.set_value(index, 'Metascore', sum1/len(list(rows["Genre"].split(','))))
    #rows["Revenue_Millions"]=sum/len(list(rows["Genre"].split(',')))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys

# %%
df.isna().sum()
# Out:
# Rank                0
# Title               0
# Genre               0
# Description         0
# Director            0
# Actors              0
# Year                0
# Runtime_Minutes     0
# Rating              0
# Votes               0
# Revenue_Millions    0
# Metascore           0
# dtype: int64

# %%
df.to_csv("ds1.csv")

# %%
# !ls
# Out:
# ds1.csv  ds.csv  sample_data

# %%
files.download("ds1.csv")

# %%
df=pd.read_csv("ds1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Rank                    Title                     Genre  \
# 0           0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1           1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2           2     3                    Split           Horror,Thriller
# 3           3     4                     Sing   Animation,Comedy,Family
# 4           4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime_Minutes  \
# ...

# %%
dir_dict={}
for index,rows in df.iterrows():
    str=rows['Director']
    if(str not in dir_dict):
      dir_dict[str]=[rows["Rating"]]
    else:
      dir_dict[str].append(rows["Rating"])
print(dir_dict)
# Out:
# {'James Gunn': [8.1, 6.5, 6.8], 'Ridley Scott': [7.0, 8.0, 6.7, 7.8, 6.0, 5.3, 6.9, 7.1], 'M. Night Shyamalan': [7.3, 6.2, 5.0, 4.2, 5.6, 4.9], 'Christophe Lourdelet': [7.2], 'David Ayer': [6.2, 7.6, 7.7], 'Yimou Zhang': [6.1], 'Damien Chazelle': [8.3, 8.5], 'Sean Foley': [6.4], 'James Gray': [7.1], 'Morten Tyldum': [7.0, 8.1], 'David Yates': [7.5, 6.3, 8.1, 7.5, 7.7, 7.5], 'Theodore Melfi': [7.8], 'Gareth Edwards': [7.9, 6.4], 'Ron Clements': [7.7, 7.1], 'Nacho Vigalondo': [6.4], 'Chris Renaud': [6.6], 'Mel Gibson': [8.2, 7.8], 'Paul Greengrass': [6.7, 8.1, 7.8], 'Garth Davis': [8.1], 'Denis Villeneuve': [8.0, 8.1, 7.6, 6.9, 8.2], 'Stephen Gaghan': [6.7], 'Kenneth Lonergan': [7.9], 'Ben Young': [6.7], 'Walt Dohrn': [6.5], 'Roland Emmerich': [5.3, 6.4, 5.8], 'Dominique Abel': [6.8], 'S.S. Rajamouli': [8.3], 'Phillip Guzman': [4.7], 'Jon Lucas': [6.2], 'Justin Kurzel': [5.9, 6.7], 'John Hamburg': [6.3], 'Tom Ford': [7.5], 'Bryan Singer': [7.1, 8.0, 6.1], 'Tim Miller': [8.0], 'Paul W.S
# ...

# %%
dir_dict_mean={}
for d in dir_dict:
  if(len(dir_dict[d])>1):
    dir_dict_mean[d]=np.mean(dir_dict[d])

# %%
dir_dict_mean
# Out:
# {'Adam McKay': 7.0,
#  'Adam Shankman': 6.300000000000001,
#  'Adam Wingard': 5.9,
#  'Alan Taylor': 6.75,
#  'Alejandro González Iñárritu': 7.766666666666667,
#  'Alexandre Aja': 6.175,
#  'Alfonso Cuarón': 7.85,
#  'Andrew Niccol': 6.300000000000001,
#  'Andrew Stanton': 7.466666666666666,
#  'Ang Lee': 7.1,
#  'Anne Fletcher': 6.6,
#  'Anthony Russo': 7.85,
#  'Antoine Fuqua': 7.040000000000001,
#  'Barry Sonnenfeld': 6.05,
#  'Baz Luhrmann': 6.949999999999999,
#  'Ben Affleck': 7.35,
#  'Ben Stiller': 6.333333333333333,
#  'Ben Wheatley': 6.35,
#  'Bill Condon': 5.2,
#  'Bong Joon Ho': 7.0,
#  'Brad Bird': 7.3,
#  'Brett Ratner': 6.35,
#  'Brian Helgeland': 7.25,
#  'Bryan Singer': 7.066666666666666,
#  'Burr Steers': 6.1,
#  'Chris Columbus': 5.75,
#  'Christian Ditter': 6.65,
#  'Christopher McQuarrie': 7.2,
#  'Christopher Nolan': 8.680000000000001,
#  'Christopher Smith': 6.6,
#  'Clint Eastwood': 7.7,
#  'D.J. Caruso': 5.875,
#  'Damien Chazelle': 8.4,
# ...

# %%
sorted_dir_dict = sorted(dir_dict_mean.items(), key=lambda kv: kv[1],reverse=True)

# %%
sorted_dir_dict[:5]
# Out:
# [('Christopher Nolan', 8.680000000000001),
#  ('Damien Chazelle', 8.4),
#  ('Rajkumar Hirani', 8.3),
#  ('Pete Docter', 8.25),
#  ('Mel Gibson', 8.0)]

# %%
plt.bar([x[0] for x in sorted_dir_dict[:5]],[y[1] for y in sorted_dir_dict[:5]])
# Out:
# <Container object of 5 artists>

# %%
sns.countplot( y='Revenue_Millions', data=df, color='b', size=8)

# %% [markdown]
# Genre Pie chart code

# %%
d={}
for index,row in df.iterrows():
  for genre in row["Genre"].split(","):
    if(genre not in d):
      d[genre]=0
    d[genre]+=1

# %%
d
# Out:
# {'Action': 303,
#  'Adventure': 259,
#  'Animation': 49,
#  'Biography': 81,
#  'Comedy': 279,
#  'Crime': 150,
#  'Drama': 513,
#  'Family': 51,
#  'Fantasy': 101,
#  'History': 29,
#  'Horror': 119,
#  'Music': 16,
#  'Musical': 5,
#  'Mystery': 106,
#  'Romance': 141,
#  'Sci-Fi': 120,
#  'Sport': 18,
#  'Thriller': 195,
#  'War': 13,
#  'Western': 7}

# %%
#d.items()
d1=d
d={}
for x in d1:
  if(not d1[x]<100):
    d[x]=d1[x]

# %%
plt.pie([x[1] for x in d.items()], labels=[x[0] for x in d.items()])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fec4711af98>,
# ...
#  [Text(1.006,0.444923,'Action'),
#   Text(0.410104,1.02069,'Adventure'),
#   Text(-0.152192,1.08942,'Sci-Fi'),
#   Text(-0.477856,0.990784,'Mystery'),
#   Text(-0.756696,0.79838,'Horror'),
#   Text(-1.02126,0.408701,'Thriller'),
#   Text(-1.05993,-0.294181,'Comedy'),
#   Text(-0.771916,-0.783674,'Fantasy'),
#   Text(0.0725091,-1.09761,'Drama'),
#   Text(0.904092,-0.626593,'Romance'),
#   Text(1.07671,-0.225153,'Crime')])

# %%
plt.boxplot(df["Revenue_Millions"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fec46fde978>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fec46fe5470>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fec46fec1d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fec46fe5d30>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fec46fdeb00>,
#   <matplotlib.lines.Line2D at 0x7fec46fdefd0>]}

# %%
plt.boxplot(df["Rating"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd4f80037b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd4f801a2b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd4f801afd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd4f801ab70>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd4f8003940>,
#   <matplotlib.lines.Line2D at 0x7fd4f8003e10>]}

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)    Metascore
# count          872.000000  1000.000000
# mean            82.956376    59.043416
# std            103.253540    16.652594
# min              0.000000    11.000000
# 25%             13.270000    47.750000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson, norm
from math import sqrt

def pos(rate, a, b, x1, x2):
    x = np.arange(a, b, 1)
    z = np.arange(a, b, 1/20)
    plt.figure(figsize=(8,4))
    plt.title('Poisson(81)')
    #plt.bar(x, poisson.pmf(x, rate), fill = False)
    plt.plot(z, norm.pdf(z, rate, sqrt(rate)))
    section = np.arange(x1, x2, 1.)
    plt.fill_between(section, poisson.pmf(section, rate))
                     
                     
pos(6.9, 45, 120, 89, 120)
   
#pos(27, 5, 50, 50, 50)

# %%
import matplotlib.pyplot as plt
from pylab import *

# fake up some data
spread= rand(50) * 100
center = ones(25) * 50
flier_high = rand(10) * 100 + 100
flier_low = rand(10) * -100
data =concatenate((spread, center, flier_high, flier_low), 0)

# figure related code
fig = plt.figure()
#fig.suptitle( fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
plt.boxplot(df["Rating"])

ax.set_title('box plot for hypothesis testing')
ax.set_xlabel('')
ax.set_ylabel('Average Rating')

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np
import pandas as pd
df=pd.read_csv("ds1.csv")
X1 = [3.01, 3.35, 4.79, 5.96, 7.89]

X2 = [3.89, 4.75, 4.75, 5.20, 5.78, 5.80, 6.33, 7.21, 7.90]

X3 = [108.047, 109.249, 103.385, 112.454, 95.780,  122.734, 109.842 , 120.858, 
      98.604, 98.122,  95.971, 98.173,   87.437 , 91.884, 92.193,  83.882]

def normality_check(data):
    pos =[]
    th_Q =[]
    data = np.sort(np.array(data))
    pos = [(i - 0.5)/len(data) for i in range(1, len(data)+1)]
    th_Q = [norm.ppf(i, np.mean(data), np.std(data, ddof = 1)) for i in pos]
    plt.plot(data, th_Q, 'ro', data, data)
    plt.xlabel("Theoritical Quantiles")
    plt.ylabel("Ordered Values")
    plt.title("Normal Probablility Plot")
    plt.show()

normality_check(X1)
normality_check(X2)
normality_check(X3)
normality_check(df["Metascore"])

# %%
df.isna().sum()
